# %% [markdown]
# <a href="https://colab.research.google.com/github/kashindra-mahato/SOC-support-system/blob/kashindra/authlog_training_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ##Imports

# %%
import pandas as pd
import numpy as np
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from scipy.spatial import distance
import matplotlib.pyplot as plt
import pickle

# %% [markdown]
# ##Parser for auth

# %%
def authParser(log_file):
  file_name = log_file
  file = open(file_name, "r")
  data = []
  order = ["date", "time", "ip", "process", "event"]
  
  for line in file.readlines():
    split1 = re.split(":", line, 3)
    event = split1[3]
    date = re.findall("^\S+\s+[0-9]{2}", line)
    time = re.findall("([0-9]{2}\\:[0-9]{2}\\:[0-9]{2})", line)[0]
    ip = re.findall("([a-z]{2}\\-[0-9]*\\-[0-9]*\\-[0-9]*\\-[0-9]*)", line)[0]
    process = re.findall("([a-zA-Z]*\\[[0-9]*\\])", line)[0]
    details = [date, time, ip, process, event]
    structure = {key:value for key, value in zip(order, details)}
    data.append(structure)
  return data

# %% [markdown]
# ##parser for single line(string)

# %%
def authParserLine(line):
  order = ["date", "time", "ip", "process", "event"]
  
  split1 = re.split(":", line, 3)
  event = split1[3]
  date = re.findall("^\S+\s+[0-9]{2}", line)
  time = re.findall("([0-9]{2}\\:[0-9]{2}\\:[0-9]{2})", line)[0]
  ip = re.findall("([a-z]{2}\\-[0-9]*\\-[0-9]*\\-[0-9]*\\-[0-9]*)", line)[0]
  process = re.findall("([a-zA-Z]*\\[[0-9]*\\])", line)[0]
  details = [date, time, ip, process, event]
  structure = {key:value for key, value in zip(order, details)}
  
  return structure

# %% [markdown]
# ##function for Cleaning

# %%
def clean(dataframe, column_name):
  dataframe[column_name] = dataframe[column_name].str.lower()
  # Remove numbers and special-characters from Event
  dataframe[column_name] = dataframe[column_name].str.replace('\d+', '')
  dataframe[column_name] = dataframe[column_name].str.replace(r'[^\w\s]+', '')
  # remove after 'user' including user :(
  dataframe[column_name] = dataframe[column_name].apply(lambda x: x.split(' user ')[0])
  return dataframe

# %% [markdown]
# ##Stop word remover

# %%
def remStopWord(dataframe, column_name, s_words):
  import nltk
  from nltk.corpus import stopwords
  nltk.download('stopwords')
  all_stopwords = stopwords.words('english')
  all_stopwords.extend(s_words)
  dataframe[column_name] = dataframe[column_name].apply(lambda x: ' '.join([word for word in x.split() if word not in (all_stopwords)]))
  return dataframe

# %% [markdown]
# ##Tokenizer

# %%
def authToken(input_data):
  return list(set(str(input_data).split(' ')))

# %% [markdown]
# ##Vectorizer

# %%
def authVectorizer(path, input_data):
  vectorizer = TfidfVectorizer(tokenizer=authToken)
  vectorizer.fit(input_data)
  vector_op = vectorizer.transform(input_data)
  pickle.dump(vectorizer, open(path + 'auth_vectorizer_model.sav', 'wb'))
  return vector_op, vectorizer

# %% [markdown]
# ##principle component analyzer

# %%
def pca(path, input_data):
  pca = PCA(n_components=0.95) 
  pca.fit(input_data)
  data = pca.transform(input_data)
  pickle.dump(pca, open(path + 'auth_pca_model.sav', 'wb'))
  return data, pca

# %% [markdown]
# ##training model

# %%
def train(path, input_data, mod):
  if mod == 'kmeans':
    model = KMeans(7)
    model.fit(input_data)
    data = model.transform(input_data)
    pickle.dump(model, open(path + 'auth_kmeans_model.sav', 'wb'))
    return data, model

  if mod == 'sgd':
    model = SGDClassifier(loss='perceptron')
    X = input_data.drop('y_label',axis=1)
    y = input_data['y_label']
    x_train, x_test, y_train, y_test = train_test_split(X, y, train_size=0.8)
    model.fit(x_train, y_train)
    pickle.dump(model, open(path + 'auth_sgd_model.sav', 'wb'))
    print(model.score(x_test, y_test))
    return model

# %% [markdown]
# ##model loader

# %%
def loadModel(path, mod_name):
  return pickle.load(open(path + 'auth_'+mod_name+'.sav', 'rb'))

# %% [markdown]
# ##function to calculate distance between each instance and their respective centroids

# %%
def fromCentDistance(pca_data, model):
  centroids = model.cluster_centers_
  df_cent = pd.DataFrame(centroids)
  df_cent['label'] = [i for i in range(len(centroids))]
  df_pca_data = pd.DataFrame(pca_data)
  df_pca_data['label'] = model.predict(pca_data)
  df_pca_data_join = df_pca_data.join(df_cent, 
                                      on='label', 
                                      how='left', 
                                      lsuffix='_pca',
                                      rsuffix='_cent')
  df_pca_1 = df_pca_data_join.loc[:, "0_pca":"label_pca"]
  df_pca_1.drop('label_pca', axis=1, inplace=True)
  df_cent_1 = df_pca_data_join.loc[:, "0_cent":"label_cent"]
  df_cent_1.drop('label_cent', axis=1, inplace=True)
  list1 = df_pca_1.to_numpy().tolist()
  list2 = df_cent_1.to_numpy().tolist()
  distances = []
  for i in range(len(list1)):
    dist = distance.euclidean(list1[i],list2[i])
    distances.append(dist)
  
  return distances

# %% [markdown]
# ##function to calculate modified_zscore

# %%
def modified_zscore(distance, consistency_correction=1.4826):
    
    median = np.median(distance)
    
    deviation_from_med = np.array(distance) - median
    
    mad = np.mean(np.abs(deviation_from_med))
    mod_zscore = deviation_from_med/(consistency_correction*mad)
    
    return mod_zscore, mad

# %% [markdown]
# ##function to plot anomalies(z>3)

# %%
def plot_anomaly(data, threshold):
    data = data.copy().sort_values(ascending=False).values
    ranks = np.linspace(1, len(data), len(data))
    mask_outliers = (data > threshold)
    
    plt.figure(dpi=100)
    plt.plot(ranks[mask_outliers], data[mask_outliers],'o', color='r',label='anomalies')
    plt.plot(ranks[~mask_outliers], data[~mask_outliers],'o', color='b', label='normal')
    plt.axhline(threshold,color='r',label='threshold', alpha=0.5)
    plt.legend(loc = 'upper right')
    plt.title('Modified z-score vs. Log Event', fontweight='bold')
    plt.xticks(np.arange(0, 21, step=2.0))
    plt.xlabel('Event')
    plt.ylabel('Modified z-score')
    plt.show()

# %% [markdown]
# #Training

# %%
# log = "/content/drive/MyDrive/Colab Notebooks/DATASET/auth.log"
log = '/home/iamdpk/Project Work/SOC-support-system/Dataset/auth.log'

# %%
path = '/home/iamdpk/Project Work/SOC-support-system/resources/auth_system/'

# %%
data = authParser(log)
data
# Out:
# [{'date': ['Nov 30'],
#   'time': '06:39:00',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[21882]',
#   'event': ' pam_unix(cron:session): session closed for user root\n'},
#  {'date': ['Nov 30'],
#   'time': '06:47:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22087]',
#   'event': ' pam_unix(cron:session): session opened for user root by (uid=0)\n'},
#  {'date': ['Nov 30'],
#   'time': '06:47:03',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22087]',
#   'event': ' pam_unix(cron:session): session closed for user root\n'},
#  {'date': ['Nov 30'],
#   'time': '07:07:14',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22116]',
#   'event': ' Connection closed by 122.225.103.87 [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '07:07:35',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22118]',
#   'event': ' Connection closed by 122.225.103.87 [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '07:08:13',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22120]',
#   'event': ' Connection closed by 122.225.103.87 [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '07:17:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22125]',
#   'event': ' pam_unix(cron:session): session opened for user root by (uid=0)\n'},
#  {'date': ['Nov 30'],
#   'time': '07:17:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22125]',
#   'event': ' pam_unix(cron:session): session closed for user root\n'},
#  {'date': ['Nov 30'],
#   'time': '08:17:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22172]',
#   'event': ' pam_unix(cron:session): session opened for user root by (uid=0)\n'},
#  {'date': ['Nov 30'],
#   'time': '08:17:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22172]',
#   'event': ' pam_unix(cron:session): session closed for user root\n'},
#  {'date': ['Nov 30'],
#   'time': '08:42:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22182]',
#   'event': ' Invalid user admin from 187.12.249.74\n'},
#  {'date': ['Nov 30'],
#   'time': '08:42:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22182]',
#   'event': ' input_userauth_request: invalid user admin [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '08:42:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22182]',
#   'event': ' Received disconnect from 187.12.249.74: 11: Bye Bye [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '08:42:14',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22184]',
#   'event': ' Did not receive identification string from 187.12.249.74\n'},
#  {'date': ['Nov 30'],
#   'time': '09:17:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22214]',
#   'event': ' pam_unix(cron:session): session opened for user root by (uid=0)\n'},
#  {'date': ['Nov 30'],
#   'time': '09:17:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22214]',
#   'event': ' pam_unix(cron:session): session closed for user root\n'},
#  {'date': ['Nov 30'],
#   'time': '09:22:03',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22218]',
#   'event': ' Did not receive identification string from 196.200.90.236\n'},
#  {'date': ['Nov 30'],
#   'time': '10:17:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22251]',
#   'event': ' pam_unix(cron:session): session opened for user root by (uid=0)\n'},
#  {'date': ['Nov 30'],
#   'time': '10:17:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22251]',
#   'event': ' pam_unix(cron:session): session closed for user root\n'},
#  {'date': ['Nov 30'],
#   'time': '10:18:55',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22254]',
#   'event': ' Did not receive identification string from 1.93.26.70\n'},
#  {'date': ['Nov 30'],
#   'time': '10:56:55',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22285]',
#   'event': ' Did not receive identification string from 122.225.109.208\n'},
#  {'date': ['Nov 30'],
#   'time': '10:57:06',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22286]',
#   'event': ' Connection closed by 122.225.109.208 [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '10:57:44',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22289]',
#   'event': ' Connection closed by 122.225.109.208 [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '10:58:27',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22291]',
#   'event': ' Invalid user admin from 122.225.109.208\n'},
#  {'date': ['Nov 30'],
#   'time': '10:58:27',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22291]',
#   'event': ' input_userauth_request: invalid user admin [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '10:58:27',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22291]',
#   'event': ' Connection closed by 122.225.109.208 [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '11:17:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22297]',
#   'event': ' pam_unix(cron:session): session opened for user root by (uid=0)\n'},
#  {'date': ['Nov 30'],
#   'time': '11:17:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22297]',
#   'event': ' pam_unix(cron:session): session closed for user root\n'},
#  {'date': ['Nov 30'],
#   'time': '11:28:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22313]',
#   'event': ' Connection closed by 122.225.109.123 [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '11:28:12',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22315]',
#   'event': ' Connection closed by 122.225.109.123 [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '11:28:24',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22317]',
#   'event': ' Connection closed by 122.225.109.123 [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '11:39:02',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22322]',
#   'event': ' Connection closed by 218.2.0.129 [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '11:39:47',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22324]',
#   'event': ' Connection closed by 218.2.0.129 [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '11:40:13',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22326]',
#   'event': ' Connection closed by 218.2.0.129 [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '11:54:48',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22343]',
#   'event': ' Connection closed by 218.2.0.121 [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '11:54:50',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22341]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '12:17:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22361]',
#   'event': ' pam_unix(cron:session): session opened for user root by (uid=0)\n'},
#  {'date': ['Nov 30'],
#   'time': '12:17:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22361]',
#   'event': ' pam_unix(cron:session): session closed for user root\n'},
#  {'date': ['Nov 30'],
#   'time': '13:17:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22396]',
#   'event': ' pam_unix(cron:session): session opened for user root by (uid=0)\n'},
#  {'date': ['Nov 30'],
#   'time': '13:17:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'CRON[22396]',
#   'event': ' pam_unix(cron:session): session closed for user root\n'},
#  {'date': ['Nov 30'],
#   'time': '13:59:21',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22430]',
#   'event': ' Received disconnect from 62.210.172.145: 11:  [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:41',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22434]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:42',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22435]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:43',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22436]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:44',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22437]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:45',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22438]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:46',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22439]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:47',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22440]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:47',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22441]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:48',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22442]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:49',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22443]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:50',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22444]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:51',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22445]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:52',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22446]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:54',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22447]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:55',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22448]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:56',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22449]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:57',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22450]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:58',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22451]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:03:59',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22452]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:00',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22453]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22454]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:03',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22456]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22457]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22458]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:05',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22459]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:09',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22460]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:10',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22461]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:11',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22462]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:18',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22463]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:18',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22465]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:19',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22466]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:20',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22467]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:22',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22468]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:23',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22469]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:24',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22470]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:25',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22471]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:26',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22472]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:27',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22473]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:28',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22474]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:29',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22475]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:30',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22476]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:31',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22477]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:32',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22478]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:33',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22479]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:34',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22480]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:35',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22481]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:36',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22482]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:37',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22483]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:38',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22484]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:39',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22485]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:40',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22486]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:42',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22488]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:43',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22489]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:44',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22490]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:44',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22491]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:45',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22492]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:46',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22493]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:47',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22494]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:48',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22495]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:49',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22496]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:50',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22497]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:51',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22498]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:52',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22499]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:59',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22500]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '14:04:59',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22502]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:00',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22503]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22504]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:02',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22505]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:03',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22506]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:12',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22508]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:13',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22510]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:14',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22511]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:15',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22513]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:16',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22514]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:17',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22515]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:18',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22516]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:24',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22517]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:24',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22519]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:25',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22520]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:26',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22521]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:27',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22522]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:28',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22523]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:32',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22524]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:33',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22525]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:34',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22526]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:35',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22527]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:46',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22528]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:48',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22531]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:49',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22532]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:50',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22533]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:52',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22534]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:53',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22535]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:54',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22536]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:56',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22538]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:56',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22539]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:59',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22540]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:05:59',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22541]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:00',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22542]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22543]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:02',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22544]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22546]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:05',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22547]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:07',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22548]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:08',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22549]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:10',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22551]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:11',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22552]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:11',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22553]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:12',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22554]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:14',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22556]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:15',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22557]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:16',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22558]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:17',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22559]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:18',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22560]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:20',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22561]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:21',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22562]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:22',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22563]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:23',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22564]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:23',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22565]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:25',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22566]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:26',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22567]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:29',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22568]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:30',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22569]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:30',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22570]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:33',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22571]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:34',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22572]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:35',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22573]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:36',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22574]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:39',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22575]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:40',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22577]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:41',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22578]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:42',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22579]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:52',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22581]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:53',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22582]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:54',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22583]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:06:55',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22584]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:02',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22585]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:03',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22587]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22588]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:05',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22589]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:06',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22590]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:07',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22591]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:08',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22592]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:09',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22593]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:10',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22594]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:11',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22595]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:12',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22596]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:13',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22597]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:14',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22598]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:15',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22599]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:16',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22600]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:20',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22601]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:22',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22602]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:24',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22605]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:25',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22606]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:26',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22607]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:26',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22608]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:27',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22609]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:29',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22610]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:30',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22611]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:31',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22612]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:32',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22613]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:33',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22614]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:34',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22615]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:36',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22617]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:38',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22619]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:40',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22621]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:41',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22622]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:43',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22624]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:44',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22625]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:45',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22626]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:46',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22627]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:51',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22628]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:51',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22630]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:52',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22631]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:55',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22632]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:57',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22633]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:58',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22634]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:07:59',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22635]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:00',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22636]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22637]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22638]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:02',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22639]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22640]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:05',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22641]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:16',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22647]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:16',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22649]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:17',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22650]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:19',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22652]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:20',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22653]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:21',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22654]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:22',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22655]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:22',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22656]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:23',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22657]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:30',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22658]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:31',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22659]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:32',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22660]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:36',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22661]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:37',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22662]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:38',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22663]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:39',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22664]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:40',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22665]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:41',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22666]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:43',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22667]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:43',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22668]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:44',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22669]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:45',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22670]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:46',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22671]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:47',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22672]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:50',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22675]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:51',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22676]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:52',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22677]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:53',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22679]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:54',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22680]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:55',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22681]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:56',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22682]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:57',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22683]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:08:58',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22684]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:02',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22685]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:03',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22686]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22687]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22688]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:05',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22689]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:06',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22690]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:07',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22691]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:09',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22692]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:10',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22693]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:11',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22694]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:12',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22695]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:17',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22696]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:19',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22698]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:20',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22699]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:20',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[22700]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': ['Nov 30'],
#   'time': '14:09:21',
# ...
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:31',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23720]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:33',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23722]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:34',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23723]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:39',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23725]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': [],
#   'time': '02:17:39',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23727]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:40',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23728]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:41',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23729]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:42',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23730]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:43',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23731]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:44',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23732]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:45',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23733]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:46',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23734]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:51',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23735]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': [],
#   'time': '02:17:51',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23737]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:52',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23738]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:53',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23739]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:54',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23740]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:55',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23741]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:56',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23742]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:57',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23743]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:57',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23744]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:58',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23745]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:17:59',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23746]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:00',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23747]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:02',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23749]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:03',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23750]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23751]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:05',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23752]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:09',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23753]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': [],
#   'time': '02:18:10',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23755]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:17',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23758]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': [],
#   'time': '02:18:18',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23761]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:19',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23762]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:21',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23764]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:27',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23769]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:27',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23770]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:29',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23772]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:30',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23773]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:33',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23777]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:38',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23778]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': [],
#   'time': '02:18:44',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23780]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': [],
#   'time': '02:18:45',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23783]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:46',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23784]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:47',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23785]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:48',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23786]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:50',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23788]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:51',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23789]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:51',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23790]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:52',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23791]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:53',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23792]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:54',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23793]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:18:58',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23794]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': [],
#   'time': '02:18:59',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23796]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:00',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23797]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23798]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:02',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23799]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:03',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23800]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23801]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:05',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23802]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:09',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23803]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': [],
#   'time': '02:19:09',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23805]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:18',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23806]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': [],
#   'time': '02:19:18',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23808]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:19',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23809]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:20',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23810]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:21',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23811]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:23',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23812]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:25',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23814]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:26',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23815]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:28',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23818]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:29',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23819]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:31',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23821]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:40',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23824]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': [],
#   'time': '02:19:52',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23826]',
#   'event': ' fatal: Read from socket failed: Connection reset by peer [preauth]\n'},
#  {'date': [],
#   'time': '02:19:53',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23829]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:54',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23830]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:54',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23831]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:56',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23832]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:56',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23833]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:57',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23834]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:19:58',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23835]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:20:00',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23836]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:20:01',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23837]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:20:02',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23838]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:20:03',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23839]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:20:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23840]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:20:04',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23841]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:20:05',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23842]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:20:06',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23843]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:20:07',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23844]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:20:08',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23845]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:20:09',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23846]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:20:10',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23847]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  {'date': [],
#   'time': '02:20:11',
#   'ip': 'ip-172-31-27-153',
#   'process': 'sshd[23848]',
#   'event': ' Did not receive identification string from 218.75.153.170\n'},
#  ...]

# %%
df = pd.DataFrame(data)

# %%
df_copy = df.copy()

# %%
df_clean = clean(df,"event")

# %%
stopwords = ['pam_unixcronsession' 'by', 'string', 'from', 'bye', 'for', 'port', 'sshd', 'ssh', 'root', 'preauth']

# %%
df_clean = remStopWord(df_clean, "event", stopwords)

# %%
vector_op, vectorizer = authVectorizer(path, df_clean['event'])

# %%
pca_data, pca = pca(path, vector_op.todense())

# %%
model_data, model = train(path, pca_data, 'kmeans')

# %%
distance = fromCentDistance(pca_data, model)

# %%
df_copy['distance'] = distance

# %%
df_copy['label'] = model.labels_

# %%
mod_zscore, mad = modified_zscore(df_copy['distance'])

# %%
df_copy['mod_zscore'] = mod_zscore.tolist()

# %%
df_copy.loc[df_copy.mod_zscore>3, 'y_label'] = 'anomaly'
df_copy.loc[df_copy.mod_zscore<3, 'y_label'] = 'normal'

# %%
df_sgd = pd.DataFrame(vector_op.todense())

# %%
df_sgd['y_label'] = df_copy['y_label']

# %%
model = train(path, df_sgd, 'sgd')

# %% [markdown]
# #Output

# %%
plot_anomaly(df_copy['mod_zscore'],3)

# %%
df.loc[df_copy.mod_zscore>3].event.unique()

# %%
df_copy.loc[df_copy.mod_zscore>3].event.unique()

# %%
df.loc[df_copy.label == 0].event.unique()

# %%
df.loc[df_copy.label == 1].event.unique()

# %%
df.loc[df_copy.label == 2].event.unique()

# %%
df.loc[df_copy.label == 3].event.unique()

# %%
df.loc[df_copy.label == 4].event.unique()

# %%
df.loc[df_copy.label == 5].event.unique()

# %%
df.loc[df_copy.label == 6].event.unique()

# %% [markdown]
# #Testing

# %%
input = "Nov 30 09:22:03 ip-172-31-27-153 sshd[22218]: Did not receive identification string from 196.200.90.236"

# %%
data1 = authParserLine(input)

# %%
df1 = pd.DataFrame(data1)

# %%
df1_copy = df1.copy()

# %%
df1_clean = clean(df1,"event")

# %%
stopwords1 = ['pam_unixcronsession' 'by', 'string', 'from', 'bye', 'for', 'port', 'sshd', 'ssh', 'root', 'preauth']

# %%
df1_clean = remStopWord(df1_clean, "event", stopwords1)

# %%
loaded_vectorizer = loadModel(path,'vectorizer_model')

# %%
vector_op1 = loaded_vectorizer.transform(df1_clean['event'])

# %%
loaded_pca = loadModel(path,'pca_model')

# %%
pca_data1 = loaded_pca.transform(vector_op1.todense())

# %%
loaded_model_kmeans = loadModel(path,'kmeans_model')

# %%
model_data1 = loaded_model_kmeans.predict(pca_data1)

# %%
model_data1

# %%
loaded_model2 = loadModel(path,'sgd_model')

# %%
model_data2 = loaded_model2.predict(pd.DataFrame(vector_op1.todense()))

# %%
model_data2
